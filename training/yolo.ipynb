# %%
from ultralytics import YOLO

# Load a YOLOv8 classification model
model = YOLO("yolov8n-cls.pt")  # small model, faster training; use yolov8s-cls.pt for bigger

# Train
results=model.train(
    data="D:/ML/Plant_classification_proj/data/30_plant_species_split",  # folder with subfolders = class names
    epochs=20,
    imgsz=224,                # image size
    batch=32,                 # adjust if you get OOM errors
    device=0,                 # GPU 0
)
# Out:
# ...
# Ultralytics 8.3.206  Python-3.10.18 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...

# %%
# # Run inference with the YOLO11n model on the  image
model = YOLO("runs/classify/train/weights/best.pt")

results = model("D:/ML/Plant_classification_proj/data/house_plant_species/Snake plant (Sanseviera)/364.jpg")  #save=True, imgsz=320, conf=0.5)
results[0].show()
# Out:
# image 1/1 D:\ML\Plant_classification_proj\data\house_plant_species\Snake plant (Sanseviera)\364.jpg: 224x224 Snake plant (Sanseviera) 0.88, Birds Nest Fern (Asplenium nidus) 0.06, Elephant Ear (Alocasia spp.) 0.03, Cast Iron Plant (Aspidistra elatior) 0.01, Peace lily 0.01, 2.7ms
# Speed: 18.5ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
